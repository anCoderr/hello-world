# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv('./Salary_Data.csv')
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.title('Salary vs Experience (TRAINING SET)')

plt.scatter(x_train, y_train, c='green', marker='.')
plt.plot(x_train, regressor.predict(x_train), linewidth=1, color='red')

plt.xlabel('Years of Experience')
plt.ylabel('Salary in USD')
plt.show()

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.title('Salary vs Experience (TEST SET)')

plt.scatter(x_test, y_test, c='green', marker='.')
plt.plot(x_test, regressor.predict(x_test), linewidth=1, color='red')

plt.xlabel('Years of Experience')
plt.ylabel('Salary in USD')
plt.show()

# %%
plt.figure(figsize=(5,3), dpi=150)

plt.title('Salary vs Experience (BOTH SET)')

plt.scatter(x_test, y_test, c='green', marker='.')
plt.scatter(x_train, y_train, c='red', marker='.')
plt.plot(x, regressor.predict(x), linewidth=1, color='black')

plt.xlabel('Years of Experience')
plt.ylabel('Salary in USD')
plt.show()
